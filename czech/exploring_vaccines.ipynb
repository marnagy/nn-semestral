# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv('vaccines.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            345 non-null    object
#  1   first_vaccine   345 non-null    int64
#  2   second_vaccine  345 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 8.2+ KB

# %%
df['date'] = df['date'].astype(np.datetime64)

row = df.loc[0]
row
# Out:
# date              2020-12-27 00:00:00
# first_vaccine                    1278
# second_vaccine                      0
# Name: 0, dtype: object

# %%
plt.plot(df['date'], df['first_vaccine'])

# %%
plt.plot(df['date'], df['second_vaccine'])
